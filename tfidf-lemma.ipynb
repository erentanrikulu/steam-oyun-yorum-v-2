# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("lemmatized_sentences.csv")

# %%
df
# Out:
#                                       simply incredible
# 0     essential patch first month addition immortal ...
# 1             game game game game official release date
# 2     still game game game game game game game game ...
# 3     still launch properly freeze launch otherwise ...
# 4             got game cdkeys ca even get refund either
# ...                                                 ...
# 3456                     wish often struggle navigation
# 3457  relying online guide find way slightly detract...
# 3458  first four chapter solid offering plenty conte...
# 3459  however chapter five six feel bit rushed could...
# 3460                                               good
#
# [3461 rows x 1 columns]

# %%
df.columns = ["0"]

# NaN değerleri ve boş stringleri temizle
df = df.dropna()
df = df[df["0"].str.strip() != ""]

# Temizlenmiş ilk 5 cümleyi göster
print(df.head())
# Out:
#                                                    0
# 0  essential patch first month addition immortal ...
# 1          game game game game official release date
# 2  still game game game game game game game game ...
# 3  still launch properly freeze launch otherwise ...
# 4          got game cdkeys ca even get refund either

# %%
#Varsayalım ki DataFrame'iniz df ve yorumlar '0' sütununda
text = ' '.join(df['0'].astype(str).tolist())  # Tüm yorumları tek bir metin haline getir
sentences = sent_tokenize(text)  # Metni cümlelere ayır

# %%
# Stopwords listesini almak
stop_words = set(stopwords.words('english'))

# %%
# Kelimeleri tokenleştirip, lemmatize etme ve stemleme
def preprocess_sentence(sentence):
    tokens = word_tokenize(sentence)  # Cümleyi kelimelere ayır
    # Sadece harf olan kelimeleri al ve stopword'leri çıkar
    filtered_tokens = [token.lower() for token in tokens if token.isalpha() and token.lower() not in stop_words]
    
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]  # Lemmatize etme
    stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]  # Stemleme
    
    return lemmatized_tokens, stemmed_tokens

# %%
# Her cümleyi tokenleştir, lemmatize et ve stemle
tokenized_corpus_lemmatized = []
tokenized_corpus_stemmed = []

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer

# Gerekli verileri indir
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# Tanımlamalar (Eksik olanlar burada)
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
for sentence in sentences:
    lemmatized_tokens, stemmed_tokens = preprocess_sentence(sentence)
    tokenized_corpus_lemmatized.append(lemmatized_tokens)
    tokenized_corpus_stemmed.append(stemmed_tokens)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Ön işlenmiş token listelerini tekrar metne çeviriyoruz
lemmatized_texts = [' '.join(tokens) for tokens in tokenized_corpus_lemmatized]

lemmatized_texts[:3]
# Out:
# ['essential patch first month addition immortal empire game simply breathtaking game game game game official release date still game game game game game game game game game game game unplayable still launch properly freeze launch otherwise gameplay freeze every second got game cdkeys ca even get refund either simply also submitted ticket focus website responded ticket saying investigating issue still fix time provide longer wasting time trying find fix almost game steam one issue issue system game clearly issue highly suggest anyone else experiencing similar issue report game broken review game wo even launch nvidia gpu amd cpu ram ssd boot game installed separate launch game pop anticheat screen loading go full screen black say responding amount troubleshooting seem fix ca even get main get launch literally click launch steam wait eventually load click anything else default setting game start set unlimited frame rate like good lord computer pushing computer absolute space heater locked framerate turning unlimited framerate realized simply act launching game push gpu cpu incredibly hard temperature reach around celsius almost able start actual campaign gameplay freeze literally almost second like chance crashing whenever freeze otherwise freeze every sometimes mission gameplay get sent loading screen saying disconnected changing host send back beginning mission absolutely everything lowest setting vsync even changed display setting main menu mission run celsius almost instantly conclusion right terrifying run game insanely hard game appears pushing system even setting turned believe game breaking something like besides also think server built magnitude bogged right something everyone paid buck completely unplayable half community black myth wukong beat game multiple ending around playtime excellent game borrowed heavily element soulsborne point could improved combat gameplay skill unlockable skill tree equivalent sekiro game spell transformation vessel spirit progress early chapter could backtrack previous even next amazing orchestrated wukong tv series version length cutscenes bossfight eyecandy something rare genre character written detail journal prepare tl dr unless storyline wished chapter felt short rush prepare fight bos within hour bit excessive subjectively statement map refer depends exploration memory also item missables throughout navigate terrain often blocked invisible wall approached edge almost superficial exploration even worse enemy knocked level back invisible wall enemy pushed weird item put reach unless using weird combo jump clipping texture empty part map also lighting glitch transitioning dark outside cave navigatecombat gameplay storyline excellent superb graphic unreal engine require latest rig order use raytracing exploration bit drawback less fun handholding invisible wall average fromsoftware enjoyer extremely hardcore shooter force think differently modern shooter call duty player going need change play style succeed offensive definitely sequel look feel familiar minor tweak help balance old issue surprise longtime player demanding multiplayer game satisfying ever specific kind player willing learn play different used look elsewhere otherwise tactic game probably share legacy predecessor dark soul iiii jump button open world elden ring evolution established design trend software studio er follows gameplay formula dark soul new added mechanic fundamentally change gameplay game derivative predecessor new element rather changing formula feel like continuation open world new element open world aspect game best realised instead following usual practise separating activity game progression er link game progression exploration make focus design core follows principle thoughtful minimalism focus combined together create game world player navigate without utilising map instead player visually lead drawn nearest objective interesting place impressive almost major location visible distance help point player  ...

# %%
# TF-IDF vektörizerı başlatıyoruz
vectorizer = TfidfVectorizer()

# TF-IDF matrisini oluşturuyoruz
#terim frekansları, belge frekanslarıni hesplar
#TF-IDF vektörlerine dönüştürür
tfidf_matrix = vectorizer.fit_transform(lemmatized_texts)

## Kelimeleri alalım
#F-IDF vektörleştirme işleminde kullanılan tüm kelimelerin essiz bir listesini döndürur
feature_names = vectorizer.get_feature_names_out()

# TF-IDF matrisini pandas DataFrame'e çevir-gorunurluk acisindan- calismasi kolay
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

# İlk birkaç satırı gösterelim-ilk 5 cümle
print(tfidf_df.head())

#Her satır bir cümleyi temsil eder
#Her sütun bir kelimeyi temsil eder
#Hücreler ise o kelimenin o cümledeki TF-IDF skorudur - her cumle icin degisir-bakiniz:slaytlar
# Out:
#         aaa  \
# 0  0.003432
#
#    ...  \
# 0                                            0.00049
#
#       aand   abandon  abandoned  abhorrent   ability      able  abrirlo  \
# 0  0.00049  0.001471   0.001471    0.00049  0.012746  0.019119  0.00049
#
#     abrupt  ...  杀着杀着就忘记了没食物的饥饿   毛毛虫mmc       解说  靠战锤续命刁大犬偷走了我的春天    鬼妹leo  \
# 0  0.00049  ...         0.00049  0.00049  0.00049          0.00049  0.00049
#
#      𝘎𝘳𝘦𝘢𝘵       𝘣𝘺  𝘤𝘩𝘦𝘢𝘵𝘦𝘳𝘴     𝘨𝘢𝘮𝘦   𝘳𝘶𝘪𝘯𝘦𝘥
# 0  0.00098  0.00098   0.00098  0.00098  0.00098
#
# [1 rows x 6149 columns]

# %%
tfidf_df.to_csv('tfidf_lemmatized1.csv', index=False)

# %%
# İlk cümle için TF-IDF skorlarını al
first_sentence_vector = tfidf_df.iloc[0]

# Skorlara göre sırala (yüksekten düşüğe)
top_5_words = first_sentence_vector.sort_values(ascending=False).head(15)

# Sonucu yazdır
print("İlk cümlede en yüksek TF-IDF skoruna sahip 5 kelime:")
print(top_5_words)
# Out:
# İlk cümlede en yüksek TF-IDF skoruna sahip 5 kelime:
# game      0.758876
# like      0.170110
# get       0.130401
# time      0.114224
# even      0.113733
# play      0.106870
# good      0.106380
# bos       0.098046
# feel      0.095595
# one       0.094614
# fun       0.087751
# player    0.081868
# really    0.079908
# new       0.078927
# make      0.077947
# Name: 0, dtype: float64

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
# player kelimesinin vektörünü alalım
player_index = feature_names.tolist().index('player')  # 'room' kelimesinin indeksini bul

# player kelimesinin TF-IDF vektörünü alıyoruz ve 2D formatta yapıyoruz
player_vector = tfidf_matrix[:, player_index].toarray()

# Tüm kelimelerin TF-IDF vektörlerini alıyoruz
tfidf_vectors = tfidf_matrix.toarray()

# Cosine similarity hesaplayalım
similarities = cosine_similarity(player_vector.T, tfidf_vectors.T)

# Benzerlikleri sıralayalım ve en yüksek 5 kelimeyi seçelim
similarities = similarities.flatten()
top_5_indices = similarities.argsort()[-6:][::-1]  # 6. en büyükten başlıyoruz çünkü kendisi de dahil

# Sonuçları yazdıralım
for index in top_5_indices:
    print(f"{feature_names[index]}: {similarities[index]:.4f}")
# Out:
# 𝘳𝘶𝘪𝘯𝘦𝘥: 1.0000
# goody: 1.0000
# flc: 1.0000
# flee: 1.0000
# fleshed: 1.0000
# flexing: 1.0000
