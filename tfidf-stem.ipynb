# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\eren\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df= pd.read_csv("stemmed_sentences.csv")

# %%
df
# Out:
#                                           simpli incred
# 0     essenti patch first month addit immort empir g...
# 1                game game game game offici releas date
# 2     still game game game game game game game game ...
# 3     still launch properli freez launch otherwis ga...
# 4              got game cdkey ca even get refund either
# ...                                                 ...
# 3456                           wish often struggl navig
# 3457  reli onlin guid find way slightli detract over...
# 3458  first four chapter solid offer plenti content ...
# 3459  howev chapter five six feel bit rush could fle...
# 3460                                               good
#
# [3461 rows x 1 columns]

# %%
df.columns = ["0"]

# NaN değerleri ve boş stringleri temizle
df = df.dropna()
df = df[df["0"].str.strip() != ""]

# Temizlenmiş ilk 5 cümleyi göster
print(df.head())
# Out:
#                                                    0
# 0  essenti patch first month addit immort empir g...
# 1             game game game game offici releas date
# 2  still game game game game game game game game ...
# 3  still launch properli freez launch otherwis ga...
# 4           got game cdkey ca even get refund either

# %%
#Varsayalım ki DataFrame'iniz df ve yorumlar '0' sütununda
text = ' '.join(df['0'].astype(str).tolist())  # Tüm yorumları tek bir metin haline getir
sentences = sent_tokenize(text)  # Metni cümlelere ayır

# %%
# Stopwords listesini almak
stop_words = set(stopwords.words('english'))

# %%
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.tokenize import word_tokenize

# Lemmatizer ve Stemmer nesnelerini oluştur
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
# Kelimeleri tokenleştirip, lemmatize etme ve stemleme
def preprocess_sentence(sentence):
    tokens = word_tokenize(sentence)
    filtered_tokens = [token.lower() for token in tokens if token.isalpha() and token.lower() not in stop_words]
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
    stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]
    return lemmatized_tokens, stemmed_tokens

# Kullanım örneği
tokenized_corpus_lemmatized = []
tokenized_corpus_stemmed = []

for sentence in sentences:
    lemmatized_tokens, stemmed_tokens = preprocess_sentence(sentence)
    tokenized_corpus_lemmatized.append(lemmatized_tokens)
    tokenized_corpus_stemmed.append(stemmed_tokens)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Ön işlenmiş token listelerini tekrar metne çeviriyoruz
lemmatized_texts = [' '.join(tokens) for tokens in tokenized_corpus_lemmatized]

lemmatized_texts[:3]
# Out:
# ['essenti patch first month addit immort empir game simpli breathtak game game game game offici releas date still game game game game game game game game game game game unplay still launch properli freez launch otherwis gameplay freez everi second got game cdkey ca even get refund either simpli also submit ticket focu websit respond ticket say investig issu still fix time provid longer wast time tri find fix almost game steam one issu issu system game clearli issu highli suggest anyon el experienc similar issu report game broken review game wo even launch nvidia gpu amd cpu ram ssd boot game instal separ launch game pop anticheat screen load goe full screen black say respond amount troubleshoot seem fix ca even get main get launch liter click launch steam wait eventu load click anyth el default set game start set unlimit frame rate like good lord comput push comput absolut space heater lock framer turn unlimit framer realiz simpli act launch game push gpu cpu incred hard temperatur reach around celsiu almost abl start actual campaign gameplay freez liter almost second like chanc crash whenev freez otherwis freez everi sometim mission gameplay get sent load screen say disconnect chang host send back begin mission absolut everyth lowest set vsync even chang display set main menu mission run celsiu almost instantli conclus right terrifi run game insan hard game appear push system even set turn believ game break someth like besid also think server built magnitud bog right someth everyon paid buck complet unplay half commun black myth wukong beat game multipl end around playtim excel game borrow heavili element soulsborn point could improv combat gameplay skill unlock skill tree equival sekiro game spell transform vessel spirit progress earli chapter could backtrack previou even next amaz orchestr wukong tv seri version length cutscen bossfight eyecandi someth rare genr charact written detail journal prepar tl dr unless storylin wish chapter felt short rush prepar fight bos within hour bit excess subject statement map refer depend explor memori also item missabl throughout navig terrain often block invis wall approach edg almost superfici explor even wors enemi knock level back invis wall enemi push weird item put reach unless use weird combo jump clip textur empti part map also light glitch transit dark outsid cave navigatecombat gameplay storylin excel superb graphic unreal engin requir latest rig order use raytrac explor bit drawback less fun handhold invis wall averag fromsoftwar enjoy extrem hardcor shooter forc think differ modern shooter call duti player go need chang play style succeed offens definit sequel look feel familiar minor tweak help balanc old issu surpris longtim player demand multiplay game satisfi ever specif kind player learn play differ use look elsewher otherwis tactic game probabl share legaci predecessor dark soul iiii jump button open world elden ring evolut establish design trend softwar studio er follow gameplay formula dark soul new ad mechan fundament chang gameplay game deriv predecessor new element rather chang formula feel like continu open world new element open world aspect game best realis instead follow usual practis separ activ game progress er link game progress explor make focu design core follow principl thought minim focu combin togeth creat game world player navig without utilis map instead player visual lead drawn nearest object interest place impress almost major locat visibl distanc help point player right direct sheer scale vertic locat spectacular instead use elabor illus make huge locat like previou game er aim make locat fulli explor massiv time addit jump button also allow interest intric level design royal capit leyndel pinnacl design biggest locat game imagin anor londo yarhnam explor everyth see open world er also introduc element nonlinear formula bloodborn becam increasingli linear nonlinear allow greater build varieti gameplay freedom player beat almost bos want order want p ...

# %%
# TF-IDF vektörizerı başlatıyoruz
vectorizer = TfidfVectorizer()

# TF-IDF matrisini oluşturuyoruz
#terim frekansları, belge frekanslarıni hesplar
#TF-IDF vektörlerine dönüştürür
tfidf_matrix = vectorizer.fit_transform(lemmatized_texts)

## Kelimeleri alalım
#F-IDF vektörleştirme işleminde kullanılan tüm kelimelerin essiz bir listesini döndürur
feature_names = vectorizer.get_feature_names_out()

# TF-IDF matrisini pandas DataFrame'e çevir-gorunurluk acisindan- calismasi kolay
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

# İlk birkaç satırı gösterelim-ilk 5 cümle
print(tfidf_df.head())

#Her satır bir cümleyi temsil eder
#Her sütun bir kelimeyi temsil eder
#Hücreler ise o kelimenin o cümledeki TF-IDF skorudur - her cumle icin degisir-bakiniz:slaytlar
# Out:
#        aaa  \
# 0  0.00326
#
#    ...  \
# 0                                           0.000466
#
#        aand   abandon    abhorr      abil       abl   abrirlo    abrupt  \
# 0  0.000466  0.002794  0.000466  0.012108  0.018163  0.000466  0.000466
#
#    abruptli  ...  杀着杀着就忘记了没食物的饥饿    毛毛虫mmc        解说  靠战锤续命刁大犬偷走了我的春天  \
# 0  0.000466  ...        0.000466  0.000466  0.000466         0.000466
#
#       鬼妹leo     𝘎𝘳𝘦𝘢𝘵        𝘣𝘺  𝘤𝘩𝘦𝘢𝘵𝘦𝘳𝘴      𝘨𝘢𝘮𝘦    𝘳𝘶𝘪𝘯𝘦𝘥
# 0  0.000466  0.000931  0.000931  0.000931  0.000931  0.000931
#
# [1 rows x 4774 columns]

# %%
tfidf_df.to_csv('tfidf_stemmed.csv', index=False)
